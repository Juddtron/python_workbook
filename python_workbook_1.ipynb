# %%
#Basic True or False Question
years = 5
if True or False:
    years = years + 2
print(years)
# Out:
# 7

# %%
#Creating a Line Chart
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 3]

plt.plot(x, y)
plt.title('Line Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
#Language Detection
pip install langid
# Out:
#   Cell In[14], line 2
#     pip install langid
#         ^
# SyntaxError: invalid syntax

# %%
import langid
def detect_language(text):
    return langid.classify(text)[0]
text = input("Enter in any language : ")
print(detect_language(text))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 def detect_language(text):
#       3     return langid.classify(text)[0]
# ----> 4 text = input("Enter in any language : ")
#       5 print(detect_language(text))
#
# File ~\anaconda4\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~\anaconda4\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
# ...

# %%
pip install rembg
# Out:
# ...
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB 3.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/5.6 MB 2.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/5.6 MB 2.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.5/5.6 MB 3.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/5.6 MB 3.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/5.6 MB 3.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/5.6 MB 3.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.2/5.6 MB 3.3 MB/s eta 0:00:02
#    --------- ------------------------------ 1.4/5.6 MB 3.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.6/5.6 MB 3.5 MB/s eta 0:00:02
#    ------------ --------------------------- 1.8/5.6 MB 3.5 MB/s eta 0:00:02
# ...

# %%
from rembg import remove
from PIL import Image
input_path = 'Harrison In the Wind.jpg'
output_path = 'Harrison In the Wind.png'
inp = Image.open(input_path)
output = remove(inp)
output.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 output_path = 'Harrison In the Wind.png'
#       5 inp = Image.open(input_path)
# ----> 6 output = remove(inp)
#       7 output.save(output_path)
#
# File ~\anaconda4\Lib\site-packages\rembg\bg.py:255, in remove(data, alpha_matting, alpha_matting_foreground_threshold, alpha_matting_background_threshold, alpha_matting_erode_size, session, only_mask, post_process_mask, bgcolor, *args, **kwargs)
#     252 img = fix_image_orientation(img)
#     254 if session is None:
# --> 255     session = new_session("u2net", *args, **kwargs)
#     257 masks = session.predict(img, *args, **kwargs)
#     258 cutouts = []
#
# File ~\anaconda4\Lib\site-packages\rembg\session_factory.py:44, in new_session(model_name, providers, *args, **kwargs)
# ...

# %%
#pip uninstall rembg
pip install rembg==2.0.52
# Out:
#   Cell In[9], line 2
#     pip install rembg==2.0.52
#         ^
# SyntaxError: invalid syntax

# %%
pip install rembg==2.0.52
# Out:
# ...
#   Attempting uninstall: rembg
#     Found existing installation: rembg 2.0.55
#     Uninstalling rembg-2.0.55:
#       Successfully uninstalled rembg-2.0.55
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from rembg import remove
from PIL import Image
input_path = 'Harrison In the Wind.jpg'
output_path = 'Harrison In the Wind.png'
inp = Image.open(input_path)
output = remove(inp)
output.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4 output_path = 'Harrison In the Wind.png'
#       5 inp = Image.open(input_path)
# ----> 6 output = remove(inp)
#       7 output.save(output_path)
#
# File ~\anaconda4\Lib\site-packages\rembg\bg.py:255, in remove(data, alpha_matting, alpha_matting_foreground_threshold, alpha_matting_background_threshold, alpha_matting_erode_size, session, only_mask, post_process_mask, bgcolor, *args, **kwargs)
#     252 img = fix_image_orientation(img)
#     254 if session is None:
# --> 255     session = new_session("u2net", *args, **kwargs)
#     257 masks = session.predict(img, *args, **kwargs)
#     258 cutouts = []
#
# File ~\anaconda4\Lib\site-packages\rembg\session_factory.py:44, in new_session(model_name, providers, *args, **kwargs)
# ...
